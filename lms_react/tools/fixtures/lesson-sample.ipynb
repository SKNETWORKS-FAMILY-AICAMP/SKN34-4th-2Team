# %% [markdown]
# # 9/15 수업 · 판다스 맛보기
# 성적 표를 만들고 평균을 그려 봅니다.

# %%
# !pip install pandas
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# old

# %%
df = pd.DataFrame({'name': ['a', 'b', 'c'], 'score': [80, 92, 75]})
df

# %%
print('평균', df.score.mean())
plt.bar(df.name, df.score)
plt.title('scores')
